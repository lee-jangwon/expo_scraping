# %%
import pandas as pd

from pathlib import Path

# %%
BASE_DIR = Path(".").absolute()

# %%
df = pd.read_csv(str(BASE_DIR/"parsed_sofurn.csv"), usecols="id,company,category,product,phone,address,description,url,sns".split(","),index_col="id")

# %%
df
# Out:
#                  company category  \
# id
# 0                 선일금고제작    스마트가전
# 1             제이앤제이인터내셔널   홈리빙&데코
# 2             음식물처리기 에코씽   스마트오피스
# 3              허리펴자 하라체어   스마트오피스
# 4                   지엘리빙   홈리빙&데코
# 5             투투 시스템 샤워기    헬스&뷰티
# 6                  돈덴디자인   홈리빙&데코
# 7                    코웨이    스마트가전
# 8                   던롭필로   홈리빙&데코
# 9                    까르핀   홈리빙&데코
# 10  조금 더 특별한 당신을 위해, 체이드   스마트오피스
# 11                  베베부아   홈리빙&데코
# 12               브리즈우드가든   홈리빙&데코
# 13                아모스아인스   홈리빙&데코
# 14                    템퍼   홈리빙&데코
# 15           척추건강 전문배게 온   홈리빙&데코
# 16                  블랑로하   홈리빙&데코
# 17             체어마이스터(주)      NaN
# 18               쓰리디 데스크   홈리빙&데코
# 19                 샤미하우스   홈리빙&데코
# 20               (주)페르모사   홈리빙&데코
# 21                    넵스   홈리빙&데코
# 22                  씨던까사   홈리빙&데코
# 23               제이우드커스텀   홈리빙&데코
# 24             (주)닥터큐메딕스    헬스&뷰티
# 25   필터이온수 샤워기 주식회사 포세이온    헬스&뷰티
# ...
